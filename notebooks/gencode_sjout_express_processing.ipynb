# %% [markdown]
# # Gencode, SJ.out, and eXpress Processing
#
# I'm going to make some useful files using the Gencode annotation
# for downstream use. I'm also going to combine the SJ.out files
# from STAR and the results files from eXpress. These files can take
# several minutes to make but we only need to do it once.

# %%
import glob
import os

import cdpybio as cpb
import ds2014 as ds
import pandas as pd

# %%
curdir = os.getcwd()
outdir = os.path.join(os.path.split(curdir)[0], 
                      'output', 
                      'gencode_sjout_express_processing')
ds.makedir(outdir)

meta = pd.read_table('../data/metadata.tsv',
                     index_col=0, header=0)

# %% [markdown]
# ## Gencode
#
# We'll parse the Gencode GTF file and make three files so that we can have easier to access to some information later on.
#
# #### `gene_info.tsv`
#
# A table with the Gencode gene ID, gene type, gene status, and gene name.
#
# #### `transcripts_genes.tsv`
#
# A table with Gencode transcript IDs and the corresponding Gencode gene ID for the gene that contains that transcript.
# #### `junction_info.tsv`
#
# A table with information about the splice junctions implied by the GTF file. Has the following columns: gene (Gencode gene ID), chrom, start, end, strand, chrom:start, chrom:end, donor, acceptor, intron. Note that the coordinates in this file are one-based and that splice junctions are represented by the one-based coordinates of the first and last base pairs of the junction's intron.
#
# It can take several minutes to make these files, but we only have to do it once.

# %%
# Get gene info
f = os.path.join(outdir, 'gene_info.tsv')
if not os.path.exists(f):
    print('Making '.format(f))
    gene_info = cpb.gencode.make_gene_info_df(ds.gencode_gtf)
    gene_info.to_csv(f, sep='\t')
else:
    gene_info = pd.read_table(f, index_col=0,
                              header=0)
print(f)

# Get mapping from transcripts to genes
f = ds.transcripts_genes
if not os.path.exists(f):
    print('Making '.format(f))
    tg = cpb.gencode.make_transcript_gene_se(ds.gencode_gtf)
    tg.to_csv(f, sep='\t')
else:
    tg = pd.read_table(f, index_col=0,
                       header=0)
print(f)
    
# Get splice junction information
f = ds.junction_info
if not os.path.exists(f):
    print('Making '.format(f))
    jxn_info = cpb.gencode.make_splice_junction_df(ds.gencode_gtf)
    jxn_info.to_csv(f, sep='\t')
else:
    jxn_info = pd.read_table(f, index_col=0,
                             header=0)
print(f)
# Out:
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/gene_info.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/transcripts_genes.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/junction_info.tsv

# %% [markdown]
# ## eXpress
#
# Now we'll combine the eXpress output for each sample. We'll make a file that represents gene expression using the mapping of transcripts to genes that we made from the Gencode GTF. The expression of a gene will be defined as the sum of the expression values of the gene's different transcripts.

# %%
def define_sample_name(x):
    """Convert filename into sample name"""
    return os.path.split(x)[1].split('_')[0]

f = ds.transcript_eff_counts
g = ds.gene_eff_counts
if (not os.path.exists(f)) or (not os.path.exists(g)):
    print('Making {} and {}'.format(f, g))
    fns = glob.glob(os.path.join(ds.expressdir,'*xprs'))
    t_counts, g_counts = cpb.express.combine_express_output(fns,
                                                            tg=ds.transcripts_genes,
                                                            define_sample_name=define_sample_name)
    t_counts.to_csv(f, sep='\t')
    g_counts.to_csv(g, sep='\t')
else:
    t_counts = pd.read_table(f, index_col=0, header=0)
    g_counts = pd.read_table(g, index_col=0, header=0)
    
print(f)
print(g)

f = ds.transcript_fpkm
g = ds.gene_fpkm
if (not os.path.exists(f)) or (not os.path.exists(g)):
    print('Making {} and {}'.format(f, g))
    fns = glob.glob(os.path.join(ds.expressdir,'*xprs'))
    t_counts, g_counts = cpb.express.combine_express_output(fns, column='fpkm',
                                                            tg=ds.transcripts_genes,
                                                            define_sample_name=define_sample_name)
    t_counts.to_csv(f, sep='\t')
    g_counts.to_csv(g, sep='\t')
else:
    t_counts = pd.read_table(f, index_col=0, header=0)
    g_counts = pd.read_table(g, index_col=0, header=0)
    
print(f)
print(g)
# Out:
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/transcript_eff_counts.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/gene_eff_counts.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/transcript_fpkm.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/gene_fpkm.tsv

# %% [markdown]
# ## STAR
#
# Now we'll combine the `SJ.out.tab` files from STAR. This relies on the [cdpybio python package](https://github.com/cdeboever3/cdpybio). First we combine all of the different `SJ.out.tab` files so that we have a file with the coverage of every junction by uniquely mapped reads. Then we filter novel junctions to keep only those that share a donor or acceptor (or both) with a known Gencode junction.
#
# ### `Log.final.out` files
#
# We'll combine together the `Log.final.out` files so we
# can look at some alignment statistics.

# %%
def define_sample_name(x):
    """Convert filename into sample name"""
    return os.path.split(x)[1].split('.')[0]

if not os.path.exists(ds.star_logs):
    logs = cpb.star.make_logs_df(glob.glob('{}/*out'.format(ds.logfinaldir)),
                                 define_sample_name=define_sample_name)
    logs.to_csv(ds.star_logs, sep='\t')
else:
    logs = pd.read_table(ds.star_logs, header=0, index_col=0)
print(ds.star_logs)
# Out:
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/star_logs.tsv

# %% [markdown]
# ### `SJ.out.tab` files
#
# #### Junction filtering
#
# ##### Unique read coverage
#
# `SJ.out.tab` files contain many unannotated junctions with low coverage. Many of these are likely noise or cannot be used in downstream analyses due to the low coverage. When combining together the `SJ.out.tab` files, we will only keep junctions that have at least 20 uniquely mapped junctions-spanning reads summed over all samples. So if a junction has 20 unique junction-spanning reads in one sample, we keep it. If a junction has one unique junction-spanning read in 20 different samples, we keep it. Other junctions are discarded. Since some analyses will only focus on a particular subset of the cancers I'm including in the study, we'll combine `SJ.out.tab` for each different subset since the coverage filtering will behave differently for different groups of samples.
#
# ##### Novel junctions
#
# There are many novel (potential) junctions in the `SJ.out.tab` files. To enrich for novel junctions that are likely real (as opposed to technical noise or something) we'll only keep novel junctions that share a donor acceptor with a known Gencode junction. Note that both a novel junction's donor and acceptor could be in Gencode but not annotated together as a splice site.

# %%
def define_sample_name(x):
    """Convert filename into sample name"""
    return os.path.split(x)[1].split('.SJ')[0]

def combine_sj_out_files(cancers, meta=meta, outdir=outdir, 
                         define_sample_name=define_sample_name):
    """Run cpb.star.combine_sj_out for all samples for a subset of cancers"""
    samples = list(meta[meta.disease_abbr.apply(lambda x: x in cancers)].index)
    fns = [ os.path.join(ds.sjoutdir, '{}.SJ.out.tab'.format(x)) for x in samples ]
    sf = os.path.join(outdir, '{}_combine_sj_out_stats.txt'.format('_'.join([ x.lower() for x in cancers ])))
    counts, annot, stats = cpb.star.combine_sj_out(fns, 
                                                   ds.junction_info,
                                                   define_sample_name=define_sample_name)
    return counts, annot, stats

# %%
cancers = ['UM']
f = ds.um_sj_counts
g = ds.um_sj_annot
h = ds.um_sj_stats
if (not os.path.exists(f)) or (not os.path.exists(g)) or (not os.path.exists(h)):
    print('Combining junctions for {}'.format(', '.join(cancers)))
    counts, annot, stats = combine_sj_out_files(cancers)
    counts.to_csv(f, sep='\t')
    annot.to_csv(g, sep='\t')
    f = open(h, 'w')
    f.write('\n'.join(stats) + '\n')
    f.close()
else:
    counts = pd.read_table(f, index_col=0, header=0)
    annot = pd.read_table(g, index_col=0, header=0)
    t = open(h)
    stats = [ x.strip() for x in t.readlines() ]
    t.close()
print(f)
print(g)
print(h)
print('\n'.join(stats))
# Out:
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/um_sj_counts.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/um_sj_annot.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/um_sj_stats.tsv
# Number of junctions in SJ.out file per sample
# SRR628589	149,532
# SRR628588	155,879
# SRR628583	184,484
# SRR628582	176,456
# SRR628587	180,954
# SRR628586	171,557
# SRR628585	171,575
# SRR628584	165,142
#
# SJ.out panel size	(8, 114426, 3)
#
# External database stats
# Read external annotation	/raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/junction_info.tsv
# Total number of junctions	346,021
# Number of junctions used in only one gene	335,976
#
# Junction filtering stats
# Number of junctions in external annotation	335,976
# Number observed junctions in STAR annotation	110,393
# Number observed junctions in external annotation	107,595
# Number of observed junctions not in external annotation	3,447
# Number of observed junctions not in external annotation but in STAR annotation	2,798
# Number of observed junctions not in external annotation and not in STAR annotation	649
# Number of novel donors	1,163
# Number of novel junctions with novel donors	1,181
# Number of novel acceptors	1,452
# Number of novel junctions with novel acceptors	1,469
# Number of novel junctions with new combination of donor and acceptor	797

# %%
cancers = ['CLL']
f = ds.cll_sj_counts
g = ds.cll_sj_annot
h = ds.cll_sj_stats
if (not os.path.exists(f)) or (not os.path.exists(g)) or (not os.path.exists(h)):
    print('Combining junctions for {}'.format(', '.join(cancers)))
    counts, annot, stats = combine_sj_out_files(cancers)
    counts.to_csv(f, sep='\t')
    annot.to_csv(g, sep='\t')
    f = open(h, 'w')
    f.write('\n'.join(stats) + '\n')
    f.close()
else:
    counts = pd.read_table(f, index_col=0, header=0)
    annot = pd.read_table(g, index_col=0, header=0)
    t = open(h)
    stats = [ x.strip() for x in t.readlines() ]
    t.close()
print(f)
print(g)
print(h)
print('\n'.join(stats))
# Out:
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/cll_sj_counts.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/cll_sj_annot.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/cll_sj_stats.tsv
# Number of junctions in SJ.out file per sample
# SA95730	351,754
# SA24823	303,139
# SA22083	445,161
# SA15699	442,822
# SA52314	348,728
# SA05603	444,627
# SA30914	473,430
# SA52609	399,459
# SA83613	528,432
# SA65385	432,073
# SA03982	353,861
# SA93051	416,274
# SA29677	350,773
# SA00242	340,552
# SA66418	442,140
# SA58773	313,381
#
# SJ.out panel size	(16, 246436, 3)
#
# External database stats
# Read external annotation	/raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/junction_info.tsv
# Total number of junctions	346,021
# Number of junctions used in only one gene	335,976
#
# Junction filtering stats
# Number of junctions in external annotation	335,976
# Number observed junctions in STAR annotation	173,725
# Number observed junctions in external annotation	156,755
# Number of observed junctions not in external annotation	60,582
# Number of observed junctions not in external annotation but in STAR annotation	16,970
# Number of observed junctions not in external annotation and not in STAR annotation	43,612
# Number of novel donors	17,188
# Number of novel junctions with novel donors	18,177
# Number of novel acceptors	23,920
# Number of novel junctions with novel acceptors	25,229
# Number of novel junctions with new combination of donor and acceptor	17,176

# %%
cancers = ['BRCA']
f = ds.brca_sj_counts
g = ds.brca_sj_annot
h = ds.brca_sj_stats
if (not os.path.exists(f)) or (not os.path.exists(g)) or (not os.path.exists(h)):
    print('Combining junctions for {}'.format(', '.join(cancers)))
    counts, annot, stats = combine_sj_out_files(cancers)
    counts.to_csv(f, sep='\t')
    annot.to_csv(g, sep='\t')
    f = open(h, 'w')
    f.write('\n'.join(stats) + '\n')
    f.close()
else:
    counts = pd.read_table(f, index_col=0, header=0)
    annot = pd.read_table(g, index_col=0, header=0)
    t = open(h)
    stats = [ x.strip() for x in t.readlines() ]
    t.close()
print(f)
print(g)
print(h)
print('\n'.join(stats))
# Out:
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/brca_sj_counts.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/brca_sj_annot.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/brca_sj_stats.tsv
# Number of junctions in SJ.out file per sample
# 71263324-796a-4f08-bba6-ecb2ae483f5a	262,712
# 12bd8213-844d-4b11-8036-d547d4112447	231,151
# 09004786-790a-48c9-b3ab-76e92f2e69dd	265,179
# 3ed7f6c6-5ab0-40cd-8da2-124a7451d287	272,056
# 01e63570-aa28-4169-81da-76e838845e78	269,335
# 766bbaa9-e498-471f-9f72-63a143e6656b	234,419
# 40dd04c6-ce5d-4c30-aaff-86ece9c78507	285,565
# d6b6eb3b-00bd-412d-a610-bc474e0cc319	223,252
# a4097518-431c-40b9-a540-2fc0d8f76e17	259,856
# ac27f4b6-daeb-4cf8-b868-54a70d30778b	261,004
# fde0f3c2-c9db-4a98-89f9-53685c482160	274,022
# 6004e153-e459-44c9-b3e7-5474bac6b953	244,289
# 5726682f-cb9d-4ccb-a5c7-0664d3ad0881	252,655
# 6685b1ee-a9b3-4f67-95c5-507847dbcd63	267,549
# 545c799d-6416-40a2-86e0-a132ed4885b3	231,074
# 059067a2-7bf7-4360-b564-3c94319ac2e2	271,313
# 646cf9ce-e8e9-4637-b843-2c6908a93a8f	317,360
# 4c9289e0-378e-4293-877c-e12d207f384e	270,185
# b6b7fb9f-129f-4baa-961b-5715adb22a62	287,795
# cd37724f-9a98-4676-b9a5-e8d6999db1f5	307,235
# d3e5466a-4861-4eb9-b5e9-f1b851afd72b	306,106
# 42857e49-6357-4fc2-966e-50c8d9ba841f	199,911
# bb496a29-fd16-4ffe-a000-4e70ea9aa76c	255,117
# 26835e9c-11f9-476f-9d6b-ebc0ae3442e8	270,073
# c52c3859-08f8-4f50-8596-bfa497a0d24f	252,050
# a0fbd146-2f78-4b9c-bc09-4f4ccd112373	260,124
# b48874ac-eaff-4ddb-b99b-1b96076914b1	249,224
# 04f38ef0-e3f5-452a-bc19-e5ae76a666ca	297,439
# d217d14a-2132-433c-bcac-ccab9d296724	258,875
# 824425ea-7871-479f-9344-328cab4f26ad	313,432
# d38df7db-3c58-4865-ae5a-e1e0b80201f1	283,866
# dfb5fd44-421f-473b-8aef-c7d275c5adcb	266,624
#
# SJ.out panel size	(32, 250210, 3)
#
# External database stats
# Read external annotation	/raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/junction_info.tsv
# Total number of junctions	346,021
# Number of junctions used in only one gene	335,976
#
# Junction filtering stats
# Number of junctions in external annotation	335,976
# Number observed junctions in STAR annotation	218,194
# Number observed junctions in external annotation	200,332
# Number of observed junctions not in external annotation	33,375
# Number of observed junctions not in external annotation but in STAR annotation	17,862
# Number of observed junctions not in external annotation and not in STAR annotation	15,513
# Number of novel donors	10,846
# Number of novel junctions with novel donors	11,109
# Number of novel acceptors	13,510
# Number of novel junctions with novel acceptors	13,792
# Number of novel junctions with new combination of donor and acceptor	8,474

# %%
cancers = ['BRCA', 'CLL', 'UM']
f = ds.brca_cll_um_sj_counts
g = ds.brca_cll_um_sj_annot
h = ds.brca_cll_um_sj_stats
if (not os.path.exists(f)) or (not os.path.exists(g)) or (not os.path.exists(h)):
    print('Combining junctions for {}'.format(', '.join(cancers)))
    counts, annot, stats = combine_sj_out_files(cancers)
    counts.to_csv(f, sep='\t')
    annot.to_csv(g, sep='\t')
    f = open(h, 'w')
    f.write('\n'.join(stats) + '\n')
    f.close()
else:
    counts = pd.read_table(f, index_col=0, header=0)
    annot = pd.read_table(g, index_col=0, header=0)
    t = open(h)
    stats = [ x.strip() for x in t.readlines() ]
    t.close()
print(f)
print(g)
print(h)
print('\n'.join(stats))
# Out:
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/brca_cll_um_sj_counts.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/brca_cll_um_sj_annot.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/brca_cll_um_sj_stats.tsv
# Number of junctions in SJ.out file per sample
# SRR628585	171,575
# 71263324-796a-4f08-bba6-ecb2ae483f5a	262,712
# 12bd8213-844d-4b11-8036-d547d4112447	231,151
# 09004786-790a-48c9-b3ab-76e92f2e69dd	265,179
# SA52609	399,459
# 3ed7f6c6-5ab0-40cd-8da2-124a7451d287	272,056
# SRR628589	149,532
# SRR628588	155,879
# SA03982	353,861
# 01e63570-aa28-4169-81da-76e838845e78	269,335
# 766bbaa9-e498-471f-9f72-63a143e6656b	234,419
# SA93051	416,274
# SA29677	350,773
# SA66418	442,140
# SRR628586	171,557
# 40dd04c6-ce5d-4c30-aaff-86ece9c78507	285,565
# SRR628584	165,142
# d6b6eb3b-00bd-412d-a610-bc474e0cc319	223,252
# SA15699	442,822
# SA22083	445,161
# SA52314	348,728
# a4097518-431c-40b9-a540-2fc0d8f76e17	259,856
# ac27f4b6-daeb-4cf8-b868-54a70d30778b	261,004
# fde0f3c2-c9db-4a98-89f9-53685c482160	274,022
# 6004e153-e459-44c9-b3e7-5474bac6b953	244,289
# 5726682f-cb9d-4ccb-a5c7-0664d3ad0881	252,655
# SA65385	432,073
# 6685b1ee-a9b3-4f67-95c5-507847dbcd63	267,549
# 545c799d-6416-40a2-86e0-a132ed4885b3	231,074
# SA58773	313,381
# SA00242	340,552
# 059067a2-7bf7-4360-b564-3c94319ac2e2	271,313
# 646cf9ce-e8e9-4637-b843-2c6908a93a8f	317,360
# SRR628587	180,954
# SA30914	473,430
# 4c9289e0-378e-4293-877c-e12d207f384e	270,185
# SA83613	528,432
# b6b7fb9f-129f-4baa-961b-5715adb22a62	287,795
# cd37724f-9a98-4676-b9a5-e8d6999db1f5	307,235
# d3e5466a-4861-4eb9-b5e9-f1b851afd72b	306,106
# 42857e49-6357-4fc2-966e-50c8d9ba841f	199,911
# SRR628583	184,484
# bb496a29-fd16-4ffe-a000-4e70ea9aa76c	255,117
# 26835e9c-11f9-476f-9d6b-ebc0ae3442e8	270,073
# SA95730	351,754
# SA24823	303,139
# c52c3859-08f8-4f50-8596-bfa497a0d24f	252,050
# a0fbd146-2f78-4b9c-bc09-4f4ccd112373	260,124
# b48874ac-eaff-4ddb-b99b-1b96076914b1	249,224
# SA05603	444,627
# 04f38ef0-e3f5-452a-bc19-e5ae76a666ca	297,439
# d217d14a-2132-433c-bcac-ccab9d296724	258,875
# 824425ea-7871-479f-9344-328cab4f26ad	313,432
# d38df7db-3c58-4865-ae5a-e1e0b80201f1	283,866
# SRR628582	176,456
# dfb5fd44-421f-473b-8aef-c7d275c5adcb	266,624
#
# SJ.out panel size	(56, 352228, 3)
#
# External database stats
# Read external annotation	/raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/junction_info.tsv
# Total number of junctions	346,021
# Number of junctions used in only one gene	335,976
#
# Junction filtering stats
# Number of junctions in external annotation	335,976
# Number observed junctions in STAR annotation	247,316
# Number observed junctions in external annotation	221,868
# Number of observed junctions not in external annotation	88,286
# Number of observed junctions not in external annotation but in STAR annotation	25,448
# Number of observed junctions not in external annotation and not in STAR annotation	62,838
# Number of novel donors	26,460
# Number of novel junctions with novel donors	27,793
# Number of novel acceptors	34,842
# Number of novel junctions with novel acceptors	36,581
# Number of novel junctions with new combination of donor and acceptor	23,912

# %%
cancers = ['BRCA', 'CLL', 'LUAD', 'LUSC', 'UM']
f = ds.brca_cll_luad_lusc_um_sj_counts
g = ds.brca_cll_luad_lusc_um_sj_annot
h = ds.brca_cll_luad_lusc_um_sj_stats
if (not os.path.exists(f)) or (not os.path.exists(g)) or (not os.path.exists(h)):
    print('Combining junctions for {}'.format(', '.join(cancers)))
    counts, annot, stats = combine_sj_out_files(cancers)
    counts.to_csv(f, sep='\t')
    annot.to_csv(g, sep='\t')
    f = open(h, 'w')
    f.write('\n'.join(stats) + '\n')
    f.close()
else:
    counts = pd.read_table(f, index_col=0, header=0)
    annot = pd.read_table(g, index_col=0, header=0)
    t = open(h)
    stats = [ x.strip() for x in t.readlines() ]
    t.close()
print(f)
print(g)
print(h)
print('\n'.join(stats))
# Out:
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/brca_cll_luad_lusc_um_sj_counts.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/brca_cll_luad_lusc_um_sj_annot.tsv
# /raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/brca_cll_luad_lusc_um_sj_stats.tsv
# Number of junctions in SJ.out file per sample
# SRR628585	171,575
# 71263324-796a-4f08-bba6-ecb2ae483f5a	262,712
# a81337f5-e346-42f0-87a2-9aab7dc1e5b4	251,770
# 3e2f068a-8235-44c6-97cb-bbf8916a3949	282,648
# fff72492-a90f-4699-a1d7-8e9186bd3cd6	285,402
# SRR628582	176,456
# 12bd8213-844d-4b11-8036-d547d4112447	231,151
# 09004786-790a-48c9-b3ab-76e92f2e69dd	265,179
# SA52609	399,459
# 48f12aef-e572-4cd8-9c5a-edda7e5385aa	229,956
# 3ed7f6c6-5ab0-40cd-8da2-124a7451d287	272,056
# SRR628589	149,532
# SRR628588	155,879
# SA03982	353,861
# 01e63570-aa28-4169-81da-76e838845e78	269,335
# 766bbaa9-e498-471f-9f72-63a143e6656b	234,419
# SA93051	416,274
# SA29677	350,773
# ead4b73b-6a51-4863-b24c-44e0fff1bbce	205,404
# SA66418	442,140
# 319489b3-2148-4cec-93fb-0540d6cda6bf	225,398
# 40dd04c6-ce5d-4c30-aaff-86ece9c78507	285,565
# SRR628584	165,142
# 23712cb6-d37f-463d-8c24-99066067c283	255,075
# d6b6eb3b-00bd-412d-a610-bc474e0cc319	223,252
# SRR628587	180,954
# SA15699	442,822
# SA22083	445,161
# SA52314	348,728
# a4097518-431c-40b9-a540-2fc0d8f76e17	259,856
# ac27f4b6-daeb-4cf8-b868-54a70d30778b	261,004
# fde0f3c2-c9db-4a98-89f9-53685c482160	274,022
# SRR628586	171,557
# 1c764fb7-631c-4425-8083-7cd27dcbc809	264,482
# 6004e153-e459-44c9-b3e7-5474bac6b953	244,289
# 5726682f-cb9d-4ccb-a5c7-0664d3ad0881	252,655
# SA65385	432,073
# 22e1471d-75ca-4259-a147-a667914e2820	227,360
# 6685b1ee-a9b3-4f67-95c5-507847dbcd63	267,549
# 545c799d-6416-40a2-86e0-a132ed4885b3	231,074
# SA58773	313,381
# SA00242	340,552
# 059067a2-7bf7-4360-b564-3c94319ac2e2	271,313
# 775f1aa3-d8aa-42a4-928f-61defc5b5134	237,025
# 646cf9ce-e8e9-4637-b843-2c6908a93a8f	317,360
# 3e82732e-8b47-4cb4-9035-22f9cdbc10c6	178,878
# f1d78984-f956-4ed0-9420-63a9e3de989b	311,631
# 870fe86d-4cb7-46a9-8d3e-2057995e763c	224,593
# SA30914	473,430
# 4c9289e0-378e-4293-877c-e12d207f384e	270,185
# SA83613	528,432
# 63b2f6d2-2f86-4986-bcc1-9e1aae13f8bd	260,288
# ff780a21-8949-4bd9-8354-7f636cbfe744	234,476
# a3a2cddb-ba5f-4dbd-a51a-555e5d758fb3	281,115
# b6b7fb9f-129f-4baa-961b-5715adb22a62	287,795
# cd37724f-9a98-4676-b9a5-e8d6999db1f5	307,235
# d3e5466a-4861-4eb9-b5e9-f1b851afd72b	306,106
# 42857e49-6357-4fc2-966e-50c8d9ba841f	199,911
# 20883c55-f271-44ea-a7d2-8806e02a088f	168,951
# SRR628583	184,484
# 5b043b12-41f4-4bd9-89eb-57e7f27cfabf	279,308
# bb496a29-fd16-4ffe-a000-4e70ea9aa76c	255,117
# 26835e9c-11f9-476f-9d6b-ebc0ae3442e8	270,073
# SA95730	351,754
# SA24823	303,139
# c52c3859-08f8-4f50-8596-bfa497a0d24f	252,050
# bc0af03f-aa40-4b39-8876-6f2e7397181c	272,787
# eaedb35d-ec72-45df-8790-18deafa143b8	302,145
# a0fbd146-2f78-4b9c-bc09-4f4ccd112373	260,124
# b48874ac-eaff-4ddb-b99b-1b96076914b1	249,224
# 1a6b6ef8-736e-424e-bcb4-b1640c15bf0e	299,083
# SA05603	444,627
# 04f38ef0-e3f5-452a-bc19-e5ae76a666ca	297,439
# 95350f94-dc26-45e6-8183-28e9c7250ade	206,208
# a35a1390-32a3-4b30-a132-3aac37c1f8cb	307,482
# d217d14a-2132-433c-bcac-ccab9d296724	258,875
# 824425ea-7871-479f-9344-328cab4f26ad	313,432
# d38df7db-3c58-4865-ae5a-e1e0b80201f1	283,866
# faba33e9-25ba-4bd5-af3d-d266e714ffa1	215,430
# 4c4b2906-f082-4fcc-83e0-039e163ee8cc	225,288
# dfb5fd44-421f-473b-8aef-c7d275c5adcb	266,624
#
# SJ.out panel size	(81, 386833, 3)
#
# External database stats
# Read external annotation	/raid2/projects/CLL/sf3b1/deboever-sf3b1-2014/output/gencode_sjout_express_processing/junction_info.tsv
# Total number of junctions	346,021
# Number of junctions used in only one gene	335,976
#
# Junction filtering stats
# Number of junctions in external annotation	335,976
# Number observed junctions in STAR annotation	264,120
# Number observed junctions in external annotation	235,862
# Number of observed junctions not in external annotation	102,678
# Number of observed junctions not in external annotation but in STAR annotation	28,258
# Number of observed junctions not in external annotation and not in STAR annotation	74,420
# Number of novel donors	31,449
# Number of novel junctions with novel donors	32,994
# Number of novel acceptors	40,217
# Number of novel junctions with novel acceptors	42,217
# Number of novel junctions with new combination of donor and acceptor	27,467
